# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, SimpleRNN
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.models import Model

# %%
series=np.sin(0.1*np.arange(200))+np.random.randn(200)*0.1
plt.plot(series)
plt.show()

# %%
T=10
D=1
X=[]
Y=[]
for t in range(len(series)-T):
    x=series[t:t+T]
    X.append(x)
    y=series[t+T]
    Y.append(y)

N=len(X)
X = np.array(X).reshape(-1,T,1)  #reshape to NxTxD
Y = np.array(Y)
print(X.shape,Y.shape)
# Out:
# (190, 10, 1) (190,)

# %%
X[0].shape
# Out:
# (10, 1)

# %%
i = Input(shape=(X[0].shape))
x = SimpleRNN(10, activation='relu')(i)
x = Dense(1)(x)
model=Model(i,x)

# %%
model.compile(loss='mse',
             optimizer=Adam(lr=0.1),
             )

# %%
r = model.fit(X[:-N//2],Y[:-N//2], epochs=80, validation_data=(X[-N//2:],Y[-N//2:]))
# Out:
# Train on 95 samples, validate on 95 samples
# Epoch 1/80
# 95/95 [==============================] - 1s 13ms/sample - loss: 0.2905 - val_loss: 0.1927
# Epoch 2/80
# 95/95 [==============================] - 0s 541us/sample - loss: 0.1007 - val_loss: 0.0318
# Epoch 3/80
# 95/95 [==============================] - 0s 535us/sample - loss: 0.0594 - val_loss: 0.0403
# Epoch 4/80
# 95/95 [==============================] - 0s 515us/sample - loss: 0.0689 - val_loss: 0.0491
# Epoch 5/80
# 95/95 [==============================] - 0s 536us/sample - loss: 0.0403 - val_loss: 0.0336
# Epoch 6/80
# 95/95 [==============================] - 0s 536us/sample - loss: 0.0432 - val_loss: 0.0360
# Epoch 7/80
# 95/95 [==============================] - 0s 546us/sample - loss: 0.0417 - val_loss: 0.0373
# Epoch 8/80
# 95/95 [==============================] - 0s 519us/sample - loss: 0.0348 - val_loss: 0.0300
# Epoch 9/80
# 95/95 [==============================] - 0s 555us/sample - loss: 0.0367 - val_loss: 0.0296
# Epoch 10/80
# 95/95 [==============================] - 0s 528us/sample - loss: 0.0363 - val_loss: 0.0323
# Epoch 11/80
# 95/95 [==============================] - 0s 514us/sample - loss: 0.0319 - val_loss: 0.0261
# Epoch 12/80
# 95/95 [==============================] - 0s 525us/sample - loss: 0.0335 - val_loss: 0.0249
# Epoch 13/80
# 95/95 [==============================] - 0s 536us/sample - loss: 0.0305 - val_loss: 0.0292
# Epoch 14/80
# 95/95 [==============================] - 0s 536us/sample - loss: 0.0336 - val_loss: 0.0247
# Epoch 15/80
# 95/95 [==============================] - 0s 546us/sample - loss: 0.0325 - val_loss: 0.0258
# Epoch 16/80
# 95/95 [==============================] - 0s 534us/sample - loss: 0.0289 - val_loss: 0.0245
# Epoch 17/80
# 95/95 [==============================] - 0s 504us/sample - loss: 0.0294 - val_loss: 0.0276
# Epoch 18/80
# 95/95 [==============================] - 0s 577us/sample - loss: 0.0271 - val_loss: 0.0239
# Epoch 19/80
# 95/95 [==============================] - 0s 557us/sample - loss: 0.0278 - val_loss: 0.0271
# Epoch 20/80
# 95/95 [==============================] - 0s 588us/sample - loss: 0.0266 - val_loss: 0.0250
# Epoch 21/80
# 95/95 [==============================] - 0s 546us/sample - loss: 0.0265 - val_loss: 0.0241
# Epoch 22/80
# 95/95 [==============================] - 0s 567us/sample - loss: 0.0263 - val_loss: 0.0234
# Epoch 23/80
# 95/95 [==============================] - 0s 577us/sample - loss: 0.0249 - val_loss: 0.0255
# Epoch 24/80
# 95/95 [==============================] - 0s 546us/sample - loss: 0.0259 - val_loss: 0.0231
# Epoch 25/80
# 95/95 [==============================] - 0s 556us/sample - loss: 0.0252 - val_loss: 0.0251
# Epoch 26/80
# Epoch 60/80
# 95/95 [==============================] - 0s 479us/sample - loss: 0.0271 - val_loss: 0.0260
# Epoch 61/80
# 95/95 [==============================] - 0s 504us/sample - loss: 0.0271 - val_loss: 0.0245
# Epoch 62/80
# 95/95 [==============================] - 0s 492us/sample - loss: 0.0226 - val_loss: 0.0252
# Epoch 63/80
# 95/95 [==============================] - 0s 525us/sample - loss: 0.0258 - val_loss: 0.0228
# Epoch 64/80
# 95/95 [==============================] - 0s 494us/sample - loss: 0.0264 - val_loss: 0.0266
# Epoch 65/80
# 95/95 [==============================] - 0s 504us/sample - loss: 0.0234 - val_loss: 0.0267
# Epoch 66/80
# 95/95 [==============================] - 0s 504us/sample - loss: 0.0235 - val_loss: 0.0231
# Epoch 67/80
# 95/95 [==============================] - 0s 500us/sample - loss: 0.0227 - val_loss: 0.0237
# Epoch 68/80
# 95/95 [==============================] - 0s 573us/sample - loss: 0.0231 - val_loss: 0.0225
# Epoch 69/80
# 95/95 [==============================] - 0s 546us/sample - loss: 0.0252 - val_loss: 0.0242
# Epoch 70/80
# 95/95 [==============================] - 0s 557us/sample - loss: 0.0239 - val_loss: 0.0234
# Epoch 71/80
# 95/95 [==============================] - 0s 556us/sample - loss: 0.0252 - val_loss: 0.0236
# Epoch 72/80
# 95/95 [==============================] - 0s 590us/sample - loss: 0.0227 - val_loss: 0.0234
# Epoch 73/80
# 95/95 [==============================] - 0s 581us/sample - loss: 0.0222 - val_loss: 0.0250
# Epoch 74/80
# 95/95 [==============================] - 0s 556us/sample - loss: 0.0241 - val_loss: 0.0236
# Epoch 75/80
# 95/95 [==============================] - 0s 567us/sample - loss: 0.0227 - val_loss: 0.0238
# Epoch 76/80
# 95/95 [==============================] - 0s 546us/sample - loss: 0.0224 - val_loss: 0.0236
# Epoch 77/80
# 95/95 [==============================] - 0s 520us/sample - loss: 0.0233 - val_loss: 0.0233
# Epoch 78/80
# 95/95 [==============================] - 0s 514us/sample - loss: 0.0235 - val_loss: 0.0232
# Epoch 79/80
# 95/95 [==============================] - 0s 535us/sample - loss: 0.0221 - val_loss: 0.0253
# Epoch 80/80
# 95/95 [==============================] - 0s 577us/sample - loss: 0.0242 - val_loss: 0.0242

# %%
plt.plot(r.history["loss"],label='loss')
plt.plot(r.history["val_loss"],label='val_loss')
plt.legend()

# %%
print(X[0],X[0].shape)
# Out:
# [[0.0926282 ]
#  [0.11786489]
#  [0.35007775]
#  [0.32377244]
#  [0.34224502]
#  [0.51697708]
#  [0.40666774]
#  [0.6824736 ]
#  [0.69512395]
#  [0.6833825 ]] (10, 1)

# %%
X[0].reshape(1,-1,1).shape
# Out:
# (1, 10, 1)

# %%
X[0].reshape(1,T,1).shape
# Out:
# (1, 10, 1)

# %% [markdown]
# # Wrong Prediction method

# %%
validation_target=Y[-N//2:]
validation_predictions=[]
i=-N//2
while(len(validation_predictions)<len(validation_target)):
    pred=model.predict(X[i].reshape(1,-1,1))[0,0]
    i+=1
    validation_predictions.append(pred)

# %%
plt.plot(validation_target,label="forcast_target")
plt.plot(validation_predictions,label="forcast_predictions")
plt.legend()

# %% [markdown]
# # Right method by not taking values of X everytime but using already made predictions

# %%
validation_target=Y[-N//2:]
validation_predictions=[]
last_x=X[-N//2]
while(len(validation_predictions)<len(validation_target)):
    pred=model.predict(last_x.reshape(1,-1,1))[0,0]
    
    validation_predictions.append(pred)
    
    last_x=np.roll(last_x,-1)
    last_x[-1]=pred

# %%
plt.plot(validation_target,label="forcast_target")
plt.plot(validation_predictions,label="forcast_predictions")
plt.legend()
